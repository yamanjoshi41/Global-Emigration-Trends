# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/yamanjoshi/Downloads/Project Spring 2025/archive/total-number-of-emigrants.csv")

# %%
df
# Out:
#            Entity  Year  Total number of emigrants
# 0     Afghanistan  1990                    7679582
# 1     Afghanistan  1995                    4347049
# 2     Afghanistan  2000                    4750677
# 3     Afghanistan  2005                    4116739
# 4     Afghanistan  2010                    5269518
# ...           ...   ...                        ...
# 1969     Zimbabwe  2000                     351985
# 1970     Zimbabwe  2005                     500773
# 1971     Zimbabwe  2010                     754643
# 1972     Zimbabwe  2015                    1167064
# 1973     Zimbabwe  2020                    1243314
#
# [1974 rows x 3 columns]

# %%
print(df.describe())
# Out:
#               Year  Total number of emigrants
# count  1974.000000               1.974000e+03
# mean   2005.000000               6.308548e+06
# std      10.002534               2.210230e+07
# min    1990.000000               0.000000e+00
# 25%    1995.000000               5.055700e+04
# 50%    2005.000000               4.416955e+05
# 75%    2015.000000               1.666904e+06
# max    2020.000000               2.805981e+08

# %%
print(df.head())
# Out:
#         Entity  Year  Total number of emigrants
# 0  Afghanistan  1990                    7679582
# 1  Afghanistan  1995                    4347049
# 2  Afghanistan  2000                    4750677
# 3  Afghanistan  2005                    4116739
# 4  Afghanistan  2010                    5269518

# %%
missing_values = df.isnull().sum()

# %%
missing_values
# Out:
# Entity                       0
# Year                         0
# Total number of emigrants    0
# dtype: int64

# %%
# Total emigration by year
emigration_by_year = df.groupby('Year')['Total number of emigrants'].sum()
emigration_by_year
# Out:
# Year
# 1990    1308370927
# 1995    1393299794
# 2000    1505945669
# 2005    1669617065
# 2010    1938364393
# 2015    2176645868
# 2020    2460830216
# Name: Total number of emigrants, dtype: int64

# %%
# Emigration Trend Over Time
plt.figure(figsize=(10, 6))
plt.plot(emigration_by_year, marker='o', color='b', linestyle='--')
plt.title('Global Emigration Trend Over Time', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Total Number of Emigrants', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(alpha=0.5)
plt.show()

# %%
top_countries = df.groupby('Entity')['Total number of emigrants'].sum().sort_values(ascending=False).head(10)
top_countries
# Out:
# Entity
# World                                                          1428493482
# Less developed regions                                          956312415
# Middle-income countries                                         901641087
# Less developed regions, excluding China                         898198454
# Less developed regions, excluding least developed countries     715774341
# Asia                                                            560656258
# Upper-middle-income countries                                   464032121
# Lower-middle-income countries                                   437608966
# Developed regions                                               408845612
# Europe and Northern America                                     396716497
# Name: Total number of emigrants, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette="mako")
plt.title('Top 10 Countries with Highest Emigration', fontsize=16)
plt.xlabel('Total Number of Emigrants', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='x', alpha=0.5)
plt.show()
